# %%
from PIL import Image

import numpy as np
import torch
import matplotlib.pyplot as plt

# %%
img1 = np.asarray(Image.open('imgs/dog1.png'))[:, :, :3]
img2 = np.asarray(Image.open('imgs/dog2.ico'))[:, :, :3]
img3 = np.asarray(Image.open('imgs/dog3.png'))[:, :, :3]
img4 = np.asarray(Image.open('imgs/dog4.jpg'))[:, :, :3]

# %%
plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()
plt.imshow(img3)
plt.show()
plt.imshow(img4)
plt.show()

# %%
from hflayers import Hopfield, HopfieldLayer, HopfieldPooling

# %%
layer = HopfieldLayer(input_size=100, )

# %%
np.sum([p.numel() for p in layer.parameters()])
# Out:
# 41100

# %%
beta=1.
hopfield = Hopfield(
    scaling=beta,

    # do not project layer input
    state_pattern_as_static=True,
    stored_pattern_as_static=True,
    pattern_projection_as_static=True,

    # do not pre-process layer input
    normalize_stored_pattern=False,
    normalize_stored_pattern_affine=False,
    normalize_state_pattern=False,
    normalize_state_pattern_affine=False,
    normalize_pattern_projection=False,
    normalize_pattern_projection_affine=False,

    # do not post-process layer output
    disable_out_projection=True)

# tuple of stored_pattern, state_pattern, pattern_projection
# hopfield((Y, R, Y))


np.sum([p.numel() for p in hopfield.parameters()])
# Out:
# 0.0

# %%
net = torch.nn.MultiheadAttention(512, 4, bias=False, )

np.sum([p.numel() for p in net.parameters()])
# Out:
# 1048576

# %%
512/4
# Out:
# 128.0

# %%
4*128*512
# Out:
# 262144

# %%
import os
import openai
openai.organization = "org-iTbCHAz451dAuWiHoMCnz7KJ"
openai.api_key = os.getenv("OPENAI_API_KEY")
openai.Engine.list()
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /var/folders/pw/m6gcpl8j3nn4yk4y5wt7_9rh0000gn/T/ipykernel_33846/2056977556.py in <module>
#       3 openai.organization = "org-iTbCHAz451dAuWiHoMCnz7KJ"
#       4 openai.api_key = os.getenv("OPENAI_API_KEY")
# ----> 5 openai.Engine.list()
#
# ~/miniconda3/lib/python3.9/site-packages/openai/api_resources/abstract/listable_api_resource.py in list(cls, api_key, request_id, api_version, organization, api_base, api_type, **params)
#      20         **params,
#      21     ):
# ---> 22         requestor = api_requestor.APIRequestor(
#      23             api_key,
#      24             api_base=api_base or cls.api_base(),
#
# ~/miniconda3/lib/python3.9/site-packages/openai/api_requestor.py in __init__(self, key, api_base, api_type, api_version, organization)
#      83     ):
#      84         self.api_base = api_base or openai.api_base
# ...

# %%
os.getenv("OPENAI_API_KEY")
